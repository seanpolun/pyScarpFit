# %%
import scipy.io as spio
import matplotlib.pyplot as plt
import main
import os
import numpy as np

# %%
matfile = "C:\\Users\\sgpq58\\Research_Share\\Post Doctoral Research\\scarp_work\\wassuk_range\\nevada_profiles.mat"
matdata = spio.loadmat(matfile)

# %%
johnstonprof1 = matdata['johnstonprof1']
x = johnstonprof1[:, 0]
z = johnstonprof1[:, 1]

johnston_scarp = main.Scarp(x, z, name="Johnston Canyon 1")

# %%
johnston_scarp.gen_ss()
johnston_scarp.gen_1e()
johnston_scarp.aspect = 1
johnston_scarp.plot_scarp('se')

# %%
out_dir = "C:\\Users\\sgpq58\\Research_Share\\Post Doctoral Research\\scarp_work\\wassuk_range"
out_name = "johnston_prof1_se.eps"
out_path = os.path.join(out_dir, out_name)
johnston_scarp.save_scarp_fig(out_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19912/1859345015.py in <module>
#       2 out_name = "johnston_prof1_se.eps"
#       3 out_path = os.path.join(out_dir, out_name)
# ----> 4 johnston_scarp.save_scarp_fig(out_path)
#
# NameError: name 'johnston_scarp' is not defined

# %%
jimprof2 = matdata['jimprof2']
plt.scatter(jimprof2[:,0], jimprof2[:,1])

# %%
jim_scarp = main.Scarp(jimprof2[:,0], jimprof2[:,1], name="Jim Canyon 1")
jim_scarp.gen_ss()
jim_scarp.gen_1e()
jim_scarp.aspect = 2
jim_scarp.plot_scarp('se')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23908/2791976304.py in <module>
# ----> 1 jim_scarp = main.Scarp(jimprof2[:,0], jimprof2[:,1], name="Jim Canyon 1")
#       2 jim_scarp.gen_ss()
#       3 jim_scarp.gen_1e()
#       4 jim_scarp.aspect = 2
#       5 jim_scarp.plot_scarp('se')
#
# ~\Documents\GitHub\pyScarpFit\main.py in __init__(self, x, z, b_fit, name)
#     644         self.z_lowres = interp_scarp(self.x_lowres)
#     645         if b_fit == 'dsp':
# --> 646             self.midx, self.midz, self.b1, self.b2, self.Hinit = dsp_scarp_identify(self.x, self.z)
#     647             # self.Hinit = 1.0
#     648         else:
#
# ~\Documents\GitHub\pyScarpFit\main.py in dsp_scarp_identify(x, z)
#     364     b2 = upper_results.params[0]
#     365     int1 = lower_results.params[1]
# --> 366     int2 = upper_results.params[1]
# ...

# %%
jim_name = "jim_prof1.png"
jim_path = os.path.join(out_dir, jim_name)
jim_scarp.save_scarp_fig(jim_path)

# %%
day2prof1 = matdata['day2prof1']
x = day2prof1[:, 0]
z = day2prof1[:, 1]
I = np.argsort(x)
x = x[I]
z = z[I]
z = np.flip(z)
plt.plot(x, z)

# %%
day2_scarp1 = main.Scarp(x, z, name="Day2 Profile 1")
day2_scarp1.gen_ss()
day2_scarp1.gen_1e()
day2_scarp1.plot_scarp('ss')

# %%
day2_1_name = "day2_prof1_ss.eps"
day2_1_path = os.path.join(out_dir, day2_1_name)
day2_scarp1.save_scarp_fig(day2_1_path)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
day2prof2 = matdata['day2prof2']
x = day2prof2[:, 0]
z = day2prof2[:, 1]
I = np.argsort(x)
x = x[I]
z = z[I]
z = np.flip(z)
# plt.plot(x, z)

day2_scarp2 = main.Scarp(x, z, name="Day2 Profile 2")
day2_scarp2.gen_ss()
day2_scarp2.gen_1e()
day2_scarp2.plot_scarp('ss')

# %%
day2_2_name = "day2_prof2_ss.png"
day2_2_path = os.path.join(out_dir, day2_2_name)
day2_scarp2.save_scarp_fig(day2_2_path)

# %%
day7prof1 = matdata['day7prof1']
x = day7prof1[:, 0]
z = day7prof1[:, 1]
I = np.argsort(x)
x = x[I]
z = z[I]
z = np.flip(z)
# plt.plot(x, z)

day7_scarp1 = main.Scarp(x, z, name="Day7 Profile 1")
day7_scarp1.gen_ss()
day7_scarp1.gen_1e()
day7_scarp1.plot_scarp('se')

# %%
day7_1_name = "day7_prof1_se.png"
day7_1_path = os.path.join(out_dir, day7_1_name)
day7_scarp1.save_scarp_fig(day7_1_path)

# %%
day7prof2 = matdata['day7prof2']
x = day7prof2[:, 0]
z = day7prof2[:, 1]
I = np.argsort(x)
x = x[I]
z = z[I]
z = np.flip(z)
# plt.plot(x, z)

day7_scarp2 = main.Scarp(x, z, name="Day7 Profile 2")
day7_scarp2.gen_ss()
day7_scarp2.gen_1e()
day7_scarp2.plot_scarp('ss')

# %%
day7_2_name = "day7_prof2_ss.png"
day7_2_path = os.path.join(out_dir, day7_2_name)
day7_scarp2.save_scarp_fig(day7_2_path)

# %%
matfile2 = "C:\\Users\\sgpq58\\Research_Share\\Post Doctoral Research\\scarp_work\\wassuk_range\\powell.mat"
matdata2 = spio.loadmat(matfile2)

# %%
powell_detail = matdata2['powell_detail']
x = powell_detail[:, 0]
z = powell_detail[:, 1]
I = np.argsort(x)
x = x[I]
z = z[I]
# z = np.flip(z)
x = x - x[0]
# plt.plot(x, z)

powell_scarp = main.Scarp(x, z, name="Powell Scarp")
powell_scarp.gen_ss()
powell_scarp.gen_1e()
powell_scarp.aspect = 3
powell_scarp.plot_scarp('se')
powell_scarp.save_scarp_fig(os.path.join(out_dir, "powell_scarp_3xve_se.png"))

# %%
matfile3 = "C:\\Users\\sgpq58\\Research_Share\\Post Doctoral Research\\scarp_work\\wassuk_range\\johnston1b.mat"
matdata3 = spio.loadmat(matfile3)

# %%
johnston1b = matdata3['johnstonprof1b']
x = johnston1b[:, 0]
z = johnston1b[:, 1]

plt.plot(x, z)

# %%
johnston1b_scarp = main.Scarp(x, z, name="Johnston Scarp 1b")
johnston1b_scarp.gen_1e()
johnston1b_scarp.sim_1e()
johnston1b_scarp.sim_ss()
johnston1b_scarp.gen_ss()

# %%
johnston1b_scarp.aspect = 1
johnston1b_scarp.plot_scarp('se', unc=True)
